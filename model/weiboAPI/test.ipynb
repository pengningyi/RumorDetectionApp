# %%
import webbrowser
import weibo

# %%
import userIndex

# %%
userIndex.get_user_index('5979571587')
# Out:
# 5979571587	烟花易冷-201607	男	1
# 1904178193	微博开放平台	女	46.7万
# 5743923782	微博会员小秘书	女	6243.8万
# 7579562933	微博社交会员	女	821万
# 1985698157	SVIP内容精选	男	1117.7万
# 5762454887	微博数据助手	男	639.4万
# 1985698157	SVIP内容精选	男	1117.7万
# 7450041147	TF家族-邓佳鑫	男	383万
# 6526319524	dive菌	女	166
# 7827771738	睡前视频基地	女	38.1万
# 7579562933	微博社交会员	女	821万
# 1985698157有重复
# 3109080617	会员剧好看	女	364.5万
# 5743923782有重复
# 7158809249	COMAPCHINAOFFICIAL	男	4.5万
# 1820201245	奥卡姆剃刀	男	1199.6万
# 2176104421	唐小雁的江湖	女	8万
# 7579562933有重复
# 1985698157有重复
# 1905099565	刘冬虹的	男	9470
# 3628056190	李三金Alex看世界	男	54.3万
# 1985698157有重复
# 7579562933有重复
# 2150758415	孤烟暮蝉	女	737.4万
# 1653076903	交通安全蜀黍	男	215.6万
# 7579562933有重复
# 7906893158	又是一年春暖花开了	女	2
# 7748141280	就似要好好嘀	男	34
# 0.49323942025731315

# %%
import sinaweibopy3
APP_KEY ='726246961'
APP_SECRET = 'e963fb052dbccfcf5b6c1776bd73ad74'
REDIRECT_URL= 'https://api.weibo.com/oauth2/default.html'
client = sinaweibopy3.APIClient(app_key=APP_KEY, app_secret=APP_SECRET, redirect_uri=REDIRECT_URL)

# %%
url = client.get_authorize_url()
webbrowser.open_new(url)
result = client.request_access_token(input("please input code : "))
client.set_access_token(result.access_token, result.expires_in)

# %%
res = client.get_uid()

# %%
print(res)
# Out:
# {'uid': 5979571587}

# %%
res = client.public_timeline().statuses

# %%
res = client.public_timeline().statuses
l = len(res)

for i in range(0,l):
    print(f'昵称：'+res[i]['user']['screen_name'])
    print(f'简介：'+res[i]['user']['description'])
    print(f'位置：'+res[i]['user']['location'])
    print(f'微博：'+res[i]['text'])
# Out:
# 昵称：中国日报
# 简介：CHINA DAILY《中国日报》在新时代，与你一起记录中国，点评世界。
# 位置：北京
# 微博：【#台湾青年看完兵马俑后背诵过秦论##台青谈美国人和炎黄子孙如何看中国文化#】4月7日下午，在参观了西安国家版本馆、兵马俑、陕西历史博物馆后，随马英九来大陆访问的台湾青年团团长刘秉叡背诵了《过秦论》。他说，自己看到兵马俑后非常震撼，足以想象当年秦军的强大。他表示：“美国人来看（这些历史 ​
# 昵称：中国日报
# 简介：CHINA DAILY《中国日报》在新时代，与你一起记录中国，点评世界。
# 位置：北京
# 微博：【#新疆开始包邮啦#！#超千万件商品实现新疆包邮#】今年，随着不少快递企业联合电商平台在新疆逐步推行包邮计划，超千万件商品实现包邮。新疆过半行政村都可以送货进村，新疆日均快递投递量增加了近百万件。有村民表示，网上买的和面机，从浙江发过来，过去拿快递只能到乡里，现在直接到家门口。(央视 ​
# 昵称：中国日报
# 简介：CHINA DAILY《中国日报》在新时代，与你一起记录中国，点评世界。
# 位置：北京
# 微博：#卖菜嬢嬢怕弄脏地铁专门准备新背篓#【#重庆菜市场给背篓菜农留免费摊位#[心]】最近，重庆地铁“背篓专线”持续引发热议。从前，有老人步行1个多小时才能到镇上，现在免费坐地铁就能去市里；有菜市场设立专门的摆摊区域，背篓菜农可以免费摆摊卖菜！
# 菜农们也处处为地铁的卫生着想，大多将菜包好，尽量 ​
# 昵称：中国日报
# 简介：CHINA DAILY《中国日报》在新时代，与你一起记录中国，点评世界。
# 位置：北京
# 微博：【“您就说对不对吧！”#消防员科普遇天津姐姐秒变相声现场#】当消防员遇到天津姐姐，绝不会让话掉地上。网友笑称，#天津人是不是人均会说相声#？做饭专不专业不知道，捧哏是真专业！温馨提示：消防员的答案才是重点！（天津消防） http://t.cn/A6TaPqSQ ​
# 昵称：中国日报
# 简介：CHINA DAILY《中国日报》在新时代，与你一起记录中国，点评世界。
# 位置：北京
# ...

# %%
res
# Out:
# {'statuses': [{'visible': {'type': 0, 'list_id': 0},
#    'created_at': 'Tue Apr 02 17:53:12 +0800 2024',
#    'id': 5018770490000134,
#    'idstr': '5018770490000134',
#    'mid': '5018770490000134',
#    'can_edit': False,
#    'version': 2,
#    'show_additional_indication': 0,
#    'text': '俄乌战事中的谣言众多，全是认知战那一套，有些专家和网友基于立场而偏听偏信，已经成为了常态。\n\n没有专业常识的普通网友也就罢了，所谓的专家以讹传讹，很可能会误导国家决策，必须澄清，我不怕得罪人。 \u200b',
#    'textLength': 190,
#    'source_allowclick': 1,
#    'source_type': 1,
#    'source': '<a href="http://app.weibo.com/t/feed/2s0OlM" rel="nofollow">HUAWEI Mate 60 Pro</a>',
#    'favorited': False,
#    'truncated': False,
#    'in_reply_to_status_id': '',
#    'in_reply_to_user_id': '',
#    'in_reply_to_screen_name': '',
#    'pic_urls': [{'thumbnail_pic': 'http://wx2.sinaimg.cn/thumbnail/001ZbnuBly1hocmta6bfyj60z01gn14602.jpg'},
#     {'thumbnail_pic': 'http://wx4.sinaimg.cn/thumbnail/001ZbnuBly1hocmtag0fuj60qo19wtj302.jpg'}],
# ...

# %%
print(result)
# Out:
# {'access_token': '2.00BjffWG0fAQJn9ca5dc129a3VBP7D', 'remind_in': '157679999', 'expires_in': 1869731568, 'uid': '5979571587', 'isRealName': 'true'}

# %%
print(client.public_timeline())
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(client.public_timeline())
#
# File ~/workspace/RumorDetectionApp/model/sinaweibopy3/sinaweibopy3.py:183, in APIClient.public_timeline(self)
#     175 def public_timeline(self):
#     176     '''
#     177     get new public weibo,the parameters followed can be used in _http_get in this method
#     178     access_token : (string) the token you got after OAuth
#    (...)
#     181     base_app : (int) whether get data in current app or not,0 is not(all data),1 is yes(current app),default 0
#     182     '''
# --> 183     result = _http_get('%s'% (self.api_url)  + 'statuses/public_timeline.json',
#     184                        access_token=self.access_token,
#     185                        count=50,
#     186                        page=1,
#     187                        base_app=0,
# ...

# %% [markdown]
# ## Another Way to Use

# %%
from weibo_api.client import WeiboClient

# %%
client = WeiboClient()
p = client.people('5623741644')

# %%
p.followers.all()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 p.followers.all()
#
# File ~/.local/lib/python3.8/site-packages/weibo_api/weibo/people.py:216, in Peoples.all(self)
#     214 if self._utype == 'follow':
#     215     return self.page_from_to(1, self._pages + 1) if self._pages < 10 else self.page_from_to(1, 10)
# --> 216 return self.page_from_to(1, self._pages + 1) if self._pages < 250 else self.page_from_to(1, 250)
#
# File ~/.local/lib/python3.8/site-packages/weibo_api/weibo/people.py:182, in Peoples._pages(self)
#     176 @property
#     177 def _pages(self):
#     178     """
#     179     粉丝or关注总页数
#     180     :return:
#     181     """
# --> 182     return int(math.ceil(self.total / 20))
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
p.followers.total
# Out:
# '41万'

# %%
p.followers_count
# Out:
# '41万'

# %%
p.name
# Out:
# 'miamaja'

# %%
p.follow_count
# Out:
# 507

# %%
cnt =0
for follw in p.follows.page(1):
    cnt+=1
    print(follw.followers.total)
    print(follw.name)
# Out:
# 284.8万
# 消费者报道
# 7100
# 氧化锌锌
# 50万
# 巧克力星星派
# 683
# SimplyThis诗肤理
# 304
# FIRSTYIN初尹
# 13.7万
# 化妆品创新实验室
# 33.5万
# 美妆圈那些事儿
# 2.3万
# Z某在言安堂
# 126万
# 微博电商客服小二
# 513.7万
# 微博美妆
# 1272
# FORFORMULA
# 541.4万
# 微博反垃圾
# 53.9万
# 坡诶佩
# 6.2万
# Vitamin2000-
# 36.6万
# 凯哥_DK
# 187.4万
# 王煊Angelo
# 4352
# 脂皮记录小S
# 8.9万
# 皮肤医美海粟医生
# 41.5万
# 南京西路没有金刚
# 20.4万
# 贺贺_旋转跳跃闭着眼

# %%
cnt=0
for status in p.statuses.page(1):
    cnt+=1
    print(status.text)
# Out:
# 📒 如果你想彻底学会护肤【本条长图】带你: 从了解自己的皮肤开始，找方法、选产品，学会科学搭配和调整产品用法<br /><br />-<br /><br />📒 【𝐌𝐢𝐚的巨型护肤目录】<a  href="https://m.weibo.cn/5623741644/4814769427319062" data-hide=""><span class='url-icon'><img style='width: 1rem;height: 1rem' src='https://h5.sinaimg.cn/upload/2015/09/25/3/timeline_card_small_web_default.png'></span><span class="surl-text">网页链接</span></a>（自助功课机）肌肤问题、肤质类型、季节护理、护肤流程、成分专题……<br /><br />🧾 选品必看（偷懒版）<a  href="https://m.weibo.cn/search?containerid=231522type%3D1%26t%3D10%26q%3D%23mia%E6%8A%A4%E8%82%A4%E6%8E%A8%E8%8D%90%E6%B8%85%E5%8D%95%23&extparam=%23mia%E6%8A%A4%E8%82%A4%E6%8E%A8%E8%8D%90%E6%B8%85%E5%8D%95%23" data-hide=""><span class="surl-text">#mia护肤推荐清单#</span></a> <br /><br />? ...<a href="/status/4814769586179666">全文</a>
# 补充两条这次救我命的内容：① 带益生菌！我吃益生菌的这两年肠应激真的缓解了很多，而且出门在外终于不会动不动就拉肚子了（只代表个人感受）②带眼霜！或者滋润一点的面霜也行，跟原文提到的清洁毛孔一样的道理，否则旱的旱死（干的地方特别干，加上频繁卸妆干纹都会出来）涝的涝死（出油毛孔超级脏
# ...

# %%
p.statuses.all()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 p.statuses.all()
#
# File ~/.local/lib/python3.8/site-packages/weibo_api/weibo/status.py:133, in Statuses.all(self)
#     128 def all(self):
#     129     """
#     130     获取用户的所有微博
#     131     :return:
#     132     """
# --> 133     return self.page_from_to(1, self._pages + 1)
#
# File ~/.local/lib/python3.8/site-packages/weibo_api/weibo/status.py:92, in Statuses._pages(self)
#      89 @property
#      90 def _pages(self):
#      91     """微博总页数"""
# ---> 92     return int(math.ceil(self.total/10))
#
# File ~/.local/lib/python3.8/site-packages/weibo_api/weibo/status.py:87, in Statuses.total(self)
#      84 @property
#      85 def total(self):
#      86     """微博总数"""
# ---> 87     return self._cardlistInfo.total
#
# ...

# %%
p.gender
# Out:
# 'f'
